# %%
import numpy as np 
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("parkinsons.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
print(df)
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# 5    phon_R01_S01_6      120.552       131.162       113.787         0.00968
# 6    phon_R01_S02_1      120.267       137.244       114.820         0.00333
# 7    phon_R01_S02_2      107.332       113.840       104.315         0.00290
# 8    phon_R01_S02_3       95.730       132.068        91.754         0.00551
# 9    phon_R01_S02_4       95.056       120.103        91.226         0.00532
# 10   phon_R01_S02_5       88.333       112.240        84.072         0.00505
# ...

# %%
print(df.isnull().sum())
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
numeric_cols = df.select_dtypes(include=['int', 'float'])
print(numeric_cols.groupby(df['status']).mean())
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  \
# status
# 0               0.162958      0.009504      0.010509  0.013305     0.028511
# 1               0.321204      0.017676      0.020285  0.027600     0.053027
#
#              NHR        HNR  status      RPDE       DFA   spread1   spread2  \
# status
# 0       0.011483  24.678750     0.0  0.442552  0.695716 -6.759264  0.160292
# 1       0.029211  20.974048     1.0  0.516816  0.725408 -5.333420  0.248133
#
#               D2       PPE
# status
# ...

# %%
X = df.drop(columns=['name', 'status'], axis=1)
Y = df['status']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
ss = StandardScaler()
ss.fit(X_train)
X_train = ss.transform(X_train)
X_test = ss.transform(X_test)
model = LogisticRegression()
model.fit(X_train, Y_train)
Y_train_pred = model.predict(X_train)
training_data_acc = accuracy_score(Y_train, Y_train_pred)
print("Training Data Accuracy Score:", training_data_acc*100)
X_test_pred = model.predict(X_test)
test_data_acc = accuracy_score(Y_test, X_test_pred)
print ("Test Data Accuracy Score = ",test_data_acc)
import warnings
warnings.filterwarnings("ignore", message="X does not have valid feature names")
input_data = np.array([input_data=(120.25600,125.30600,104.77300,0.00407,0.00003,0.00224,0.00205,0.00671,0.01516,0.13800,0.00721,0.00815,0.01310,0.02164,0.01015,26.01700,0.468621,0.735136,-6.112667,0.217013,2.527742,0.170633)]).reshape(1, -1)
input_data_standardized = ss.transform(input_data)
pred = model.predict(input_data_standardized)
if pred[0] == 0:
    print("Negative: This person does not have Parkinson's Disease")
else:
    print("Positive: This person has Parkinson's Disease")
# Out:
# Training Data Accuracy Score: 87.17948717948718
# Negative: This person does not have Parkinson's Disease
